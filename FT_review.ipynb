# %%
import re


def classify(txt):
    prio_list = ["Brief review", "Code review", "Complete review", "Comprehensive review", "Critical review", "Exhaustive review", "General review", "Integrated review", "Literature review", "Mapping review", "Meta analysis", "Mixed methods review", "Model-oriented review", "Overview", "Qualitative systematic review", "Rapid review", "Review", "Scoping review", "State-of-the-art review", "Systematic review", "Technical review", "Topology review", "Umbrella review", "Evidence based software Engineering"]
    matchers = {"Brief review": "[Bb]rief [Rr]eview", "Code review": "code_review", "Complete review":"[Cc]omplete [Rr]eview", "Comprehensive review":"[Cc]omprehensive [Rr]eview", "Critical review":"[Cc]ritical [Rr]eview", "Exhaustive review":"[Ee]xhaustive [Rr]eview", "General review":"[Gg]eneral [Rr]eview", "Integrated review":"[Ii]ntegrated [Rr]eview", "Literature review":"[Ll]iterature [Rr]eview", "Mapping review":"[Mm]apping [Rr]eview", "Meta analysis":"[Mm]eta [Aa]nalysis", "Mixed methods review":"[Mm]ixed [Mm]ethods [Rr]eview", "Model-oriented review":"[Mm]odel-oriented [Rr]eview", "Overview":"[Oo]verview", "Qualitative systematic review":"[Qq]ualitative [Ss]ystematic [Rr]eview", "Rapid review":"[Rr]apid [Rr]eview", "Review":"[Rr]eview", "Scoping review":"[Ss]coping [Rr]eview", "State-of-the-art review":"[Ss]tate-of-the-art", "Systematic review":"[Ss]ystematic [Rr]eview", "Technical review":"[Tt]echnical [Rr]eview", "Topology review":"[Tt]opology [Rr]eview", "Umbrella review":"[Uu]mbrella [Rr]eview", "Evidence based software Engineering":"[Ee]vidence [Bb]ased [Ss]oftware [Ee]ngineering"}
    for category in prio_list:
        count = 0
        for match in re.findall(matchers[category], txt):
            count += 1
        if re.findall(matchers[category], txt):
            print (category)
            print (count)

# %%
with open('/Users/JustinRoy/Desktop/savedrecs.csv', encoding="utf8") as f:
    for index, row in enumerate(f):
        print("Row {}:".format(index, row.strip())) 
        classify(row)
# Out:
# Row 0:
# Row 1:
# Review
# 3
# State-of-the-art review
# 2
# Row 2:
# Literature review
# 1
# Review
# 6
# Systematic review
# 2
# Row 3:
# Review
# 6
# State-of-the-art review
# 1
# Systematic review
# 2
# Row 4:
# Literature review
# 2
# Review
# 11
# Row 5:
# Critical review
# 1
# Literature review
# 2
# Review
# 5
# Row 6:
# Critical review
# 1
# Literature review
# 2
# Review
# 5
# Row 7:
# Literature review
# 2
# Review
# 3
# Row 8:
# Overview
# 1
# Review
# 3
# State-of-the-art review
# 1
# Row 9:
# Review
# 2
# State-of-the-art review
# 2
# Row 10:
# Literature review
# 2
# Review
# 3
# Row 11:
# Literature review
# 2
# Review
# 3
# Row 12:
# Overview
# 1
# Review
# 4
# Row 13:
# Review
# 3
# Systematic review
# 1
# Row 14:
# Review
# 3
# Systematic review
# 2
# Row 15:
# Literature review
# 2
# Review
# 5
# Row 16:
# Review
# 4
# Row 17:
# Literature review
# 1
# Review
# 3
# Systematic review
# 1
# Row 18:
# Literature review
# 1
# Review
# 1
# Row 19:
# Review
# 3
# Row 20:
# Comprehensive review
# 1
# Literature review
# 2
# Review
# 4
# Row 21:
# Literature review
# 2
# Review
# 5
# Systematic review
# 1
# Row 22:
# Literature review
# 2
# Review
# 4
# State-of-the-art review
# 1
# Row 23:
# Critical review
# 1
# Exhaustive review
# 1
# Literature review
# 1
# Review
# 6
# Row 24:
# Literature review
# 2
# Review
# 4
# Row 25:
# Review
# 4
# Row 26:
# Review
# 6
# Row 27:
# Overview
# 1
# Row 28:
# Literature review
# 1
# Overview
# 1
# Review
# 1
# Row 29:
# Literature review
# 2
# Review
# 2
# Row 30:
# Overview
# 1
# Review
# 2
# Row 31:
# Literature review
# 1
# Review
# 2
# Row 32:
# Review
# 2
# Systematic review
# 1
# Row 33:
# Literature review
# 1
# Review
# 2
# Row 34:
# Literature review
# 1
# Review
# 1
# Row 35:
# Review
# 10
# Row 36:
# Literature review
# 1
# Review
# 2
# Row 37:
# Row 38:
# Literature review
# 1
# Overview
# 1
# Review
# 4
# Row 39:
# Review
# 9
# Row 40:
# Review
# 3
# Row 41:
# Review
# 12
# Row 42:
# Review
# 10
# Row 43:
# Literature review
# 1
# Review
# 1
# Row 44:
# Overview
# 1
# Review
# 3
# Row 45:
# Literature review
# 1
# Overview
# 1
# Review
# 1
# Row 46:
# Review
# 4
# Row 47:
# Overview
# 2
# Row 48:
# Overview
# 1
# Review
# 1
# Row 49:
# Comprehensive review
# 1
# Literature review
# 1
# Review
# 3
# Row 50:
# Comprehensive review
# 2
# Literature review
# 1
# Review
# 4

# %%
import csv

a = open ('/Users/JustinRoy/Desktop/savedrecs.csv', 'r', encoding="utf8")

f = open('/Users/JustinRoy/Desktop/savedrecs1.csv', 'w', encoding="utf8")
writer = csv.writer(f)
next (a)
for index, row in enumerate(a):
    matchArray = classify(row)
    print (matchArray)
    for element in matchArray :
        #print (element)
        row = row + str(element)
        #print (row)
    #print (matchArray)
    #matchfound = row + matchArray
    #writer.writerow(row)

# %%
import re


def classify(txt):
    prio_list = ["Brief review", "Code review", "Complete review", "Comprehensive review", "Critical review", "Exhaustive review", "General review", "Integrated review", "Literature review", "Mapping review", "Meta analysis", "Mixed methods review", "Model-oriented review", "Overview", "Qualitative systematic review", "Rapid review", "Review", "Scoping review", "State-of-the-art review", "Systematic review", "Technical review", "Topology review", "Umbrella review", "Evidence based software Engineering"]
    matchers = {"Brief review": "[Bb]rief [Rr]eview", "Code review": "code_review", "Complete review":"[Cc]omplete [Rr]eview", "Comprehensive review":"[Cc]omprehensive [Rr]eview", "Critical review":"[Cc]ritical [Rr]eview", "Exhaustive review":"[Ee]xhaustive [Rr]eview", "General review":"[Gg]eneral [Rr]eview", "Integrated review":"[Ii]ntegrated [Rr]eview", "Literature review":"[Ll]iterature [Rr]eview", "Mapping review":"[Mm]apping [Rr]eview", "Meta analysis":"[Mm]eta [Aa]nalysis", "Mixed methods review":"[Mm]ixed [Mm]ethods [Rr]eview", "Model-oriented review":"[Mm]odel-oriented [Rr]eview", "Overview":"[Oo]verview", "Qualitative systematic review":"[Qq]ualitative [Ss]ystematic [Rr]eview", "Rapid review":"[Rr]apid [Rr]eview", "Review":"[Rr]eview", "Scoping review":"[Ss]coping [Rr]eview", "State-of-the-art review":"[Ss]tate-of-the-art", "Systematic review":"[Ss]ystematic [Rr]eview", "Technical review":"[Tt]echnical [Rr]eview", "Topology review":"[Tt]opology [Rr]eview", "Umbrella review":"[Uu]mbrella [Rr]eview", "Evidence based software Engineering":"[Ee]vidence [Bb]ased [Ss]oftware [Ee]ngineering"}
    matchList = []
    for category in prio_list:
        count = 0
        for match in re.findall(matchers[category], txt):
            count += 1
        if re.findall(matchers[category], txt):
            if category != None :
                #matchList.append(category)
                #matchList.append(count)
                print (category)
                print (count)

import csv

a = open ('/Users/JustinRoy/Desktop/savedrecs.csv', 'r', encoding="utf8")

f = open('/Users/JustinRoy/Desktop/savedrecs1.csv', 'w', encoding="utf8")
writer = csv.writer(f)
csvfile = csv.reader(a)
next (a)
for line in csvfile :
    print (line)
#for index, row in enumerate(a):
    matchArray = classify(row)
    print (matchArray)
    for element in matchArray :
        print (element)
        row = row + str(element)
        print (row)
    #print (matchArray)
    #matchfound = row + matchArray
    #writer.writerow(row)
# Out:
# ['Godat, A; Hammad, F; Chaallal, O;State-of-the-art review of anchored FRP shear-strengthened RC beams: A study of influencing factors;COMPOSITE STRUCTURES;Review;Several anchorage techniques have been proposed in the literature to delay or prevent the debonding failure mode and to upgrade and restore the capacity of externally bonded (EB) fiber-reinforced polymers (FRPs) shear-strengthened beams in a U-wrapping scheme', ' such as NSM', ' FRP extension', ' FRP insertion', ' horizontal FRP', ' FRP patch', ' FRP rope', ' FRP spike', ' metallic anchors', ' and combined anchors. Although the advantages of these anchorage techniques have been acknowledged by researchers', ' their effectiveness in enhancing FRP shear contribution is controversial. The present study is a state-of-the-art review of experimental tests that were carried out to investigate the effectiveness of anchorage techniques for FRP shear-strengthened beams. The various anchorage techniques are evaluated in terms of FRP shear strength and FRP strain based on the parameters that have a major influence on the behavior of FRP shear-strengthened beams. Furthermore', ' strength models for FRP shear-strengthened beams provided in various design guidelines are used to predict FRP shear strength compared to experimental results. The significance of the present findings with respect to FRP shear contribution is discussed.;2020;10.1016/j.compstruct.2020.112767;http://dx.doi.org/10.1016/j.compstruct.2020.112767;WOS:000579724400003']
# Comprehensive review
# 2
# Literature review
# 1
# Review
# 4
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 27>()
#      30 matchArray = classify(row)
#      31 print (matchArray)
# ---> 32 for element in matchArray :
#      33     print (element)
#      34     row = row + str(element)
#
# TypeError: 'NoneType' object is not iterable
